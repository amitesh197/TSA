# %%
#LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
from statsmodels.tsa.filters.hp_filter import hpfilter
df = pd.read_csv('/content/shampoo.csv',index_col=0,parse_dates = True)
SALES_cycle,SALES_trend = hpfilter(df['Sales'],lamb = 1600)
SALES_trend.plot(figsize = (15,6)).autoscale(axis = 'x')
plt.ylabel("Sales")
plt.title("Time Series analysis")
plt.show()

# %%
from pandas.io.excel import read_excel
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
import matplotlib.pyplot as plt

series = read_excel('India_Exchange_Rate_Dataset.xls',index_col= 0,parse_dates = True)
x = series.values
diff = list()
for i in range(1,len(x)):
  value =x[i] - x[i-1]
  diff.append(value)
plt.figure(figsize =(15,6))
pyplot.plot(diff)
# Out:
# <ipython-input-4-c4649f7fcdb8>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
df1 = pd.read_csv('/content/shampoo.csv',index_col=0,parse_dates = True)
diff  = df1.Sales.diff()
plt.figure(figsize = (15,6))
plt.plot(diff)
plt.title('Detrending using Pandas Differencing',fontsize = 16)
plt.xlabel('Year')
plt.ylabel('Sales rate')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
df2 = pd.read_csv('/content/shampoo.csv',index_col=0,parse_dates = True)
detrended = signal.detrend(df2.Sales.values)
plt.figure(figsize = (15,6))
plt.plot(detrended)
plt.title('Detrending using Scipy signal',fontsize = 16)
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
from statsmodels.tsa.filters.hp_filter import hpfilter
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
df = pd.read_csv('/content/shampoo.csv',index_col=0,parse_dates = True)
SALES_cycle,SALES_trend = hpfilter(df['Sales'],lamb = 1600)
df['trend'] = SALES_trend
detrended = df.Sales - df['trend']
plt.figure(figsize = (15,6))
plt.plot(detrended)
plt.title('Detrending using HP Filter',fontsize = 16)
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
# %matplotlib inline
from statsmodels.tsa.filters.hp_filter import hpfilter
df = read_excel('India_Exchange_Rate_Dataset.xls',index_col= 0,parse_dates = True)
SALES_cycle,SALES_trend = hpfilter(df['EXINUS'],lamb = 1600)
SALES_trend.plot(figsize = (15,6)).autoscale(axis = 'x')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
df = read_excel('India_Exchange_Rate_Dataset.xls',index_col= 0,parse_dates = True)
diff  = df1.Sales.diff()
plt.figure(figsize = (15,6))
plt.plot(diff)
plt.title('Detrending using Pandas Differencing',fontsize = 16)
plt.xlabel('Year')
plt.ylabel('EXINUS')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
df2 = read_excel('India_Exchange_Rate_Dataset.xls',index_col= 0,parse_dates = True)
detrended = signal.detrend(df2.EXINUS.values)
plt.figure(figsize = (15,6))
plt.plot(detrended)
plt.title('Detrending using Scipy signal',fontsize = 16)
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
from statsmodels.tsa.filters.hp_filter import hpfilter
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
df = read_excel('India_Exchange_Rate_Dataset.xls',index_col= 0,parse_dates = True)
EXINUS_cycle,EXINUS_trend = hpfilter(df['EXINUS'],lamb = 1600)
df['trend'] = EXINUS_trend
detrended = df.EXINUS - df['trend']
plt.figure(figsize = (15,6))
plt.plot(detrended)
plt.title('Detrending using HP Filter',fontsize = 16)
plt.xlabel('EXINUS')
plt.ylabel('Frequency')
plt.show()
